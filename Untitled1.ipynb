# %%
import tornado.web
import tornado.httpserver
import tornado.ioloop
import torndsession
from torndsession.sessionhandler import SessionBaseHandler
import random
from random import randrange
from pyroaring import BitMap
from datetime import datetime
from datetime import timedelta


def expiration_date(start = datetime.strptime('7/1/2020 1:30 PM', '%m/%d/%Y %I:%M %p'), end= datetime.now()):                   
    difference = end -start
    seconds = (difference.days * 24 * 60 * 60) + difference.seconds
    random_second = randrange(seconds)
    random_day = randrange(30)
    rand_date = start + timedelta(days=random_day,seconds=random_second)
    if (rand_date - datetime.now()).total_seconds() > 0:
        rand_date = start + timedelta(seconds=random_second)
        return rand_date
    else:
        return rand_date

def last_week_visit(past_date):    
    now = datetime.now()
    past = past_date 
    difference = (past - now).total_seconds()
    
    return abs(difference /(60 * 60 * 24)) <= 7

class Application(tornado.web.Application):
    def __init__(self):
        handlers = [
            (r"/([0-9]+)", MainHandler),
            (r"/", MyHandler)
        ]
        settings = dict(
            debug=True,
        ),        
        tornado.web.Application.__init__(self, handlers)
        
# class MainHandler(SessionBaseHandler):
#     def get(self):
#         self.write("Memory Session Object Demo:<br/>")
#         if "sv" in self.session:
#             current_value = self.session["sv"]
#         else:
#             current_value = 0
#         if not current_value:
#             self.write("current_value is None(0)<br/>")
#             current_value = 1
#         else:
#             current_value = int(current_value) + 1
#         self.write('<br/> Current Value is: %d' % current_value)
#         self.write('<br/>Current Python Version: %s' % version)
#         self.session["sv"] = current_value


class MainHandler(tornado.web.RequestHandler):

    def get(self, id):
        if int(id) > 100:
            id = 100
            self.write("Maximum number of sessions was set to {}\n\n".format(id))
            
        for y in range(1, 11):
            globals()['tag%s' % y] = BitMap()
        
        weekly_visit = BitMap()
        #self.write('<h3>Invalid username</h3>')
        #self.write("<html><head></head><body><h3>This is a Tornado API project<h3><hr></body></html>")
        self.write("-----------------------------------------------------------\n")
        self.write("Show the first 10 Users\n")
        self.write("-----------------------------------------------------------\n\n")
        for i in range(1, int(id)+1):
            setter = randrange(10)
            if setter == 0:
                tag1.add(i)
            elif setter == 1:
                tag2.add(i)
            else:
                pass

            session_time = expiration_date()            
            visited = last_week_visit(session_time)
            if visited: weekly_visit.add(i)
                
            session_time = session_time.isoformat()
            
            setter = "tag_" + str(setter+1) + "_" + session_time
            session = self.set_cookie(name = str(i), value = setter)  #,expires = expiration_date()
#             retrieve = self.request.cookies.get(setter)

            if i <= 10: self.write("The {} cookie was set with :  {}\n".format(i, setter))
#         self.render("index.html")
        self.write("\n-----------------------------------------------------------")
        self.write("\n\n>>  Total Number of Users are: {}\n".format(id))
        self.write("\n>>  Number of Users have NOT logged in for a week: {}\n".format(len(list(weekly_visit))))
        self.write("\n>>  Number of Users with tag1 and tag2 are: {}\n"
                   .format(len(list(tag1))+ len(list(tag2))))
        self.write("\n>>  The User ID's with tag1 are below:\n\n")
        self.finish({'tag1': list(tag1)})
                    

# Concurrent user testing measures how long it takes the server
# to respond to a specified number of simultaneous requests



class MyHandler(MainHandler):

    def get(self):
        for cookie_key in self.request.cookies.keys():
            cookie = self.request.cookies[cookie_key]
            self.write("{}\n".format(cookie.output()))
#             name = cookie
#             r = cookie.match("\\b" + name + "=([^;]*)\\b");
#             return r ? r[1] : undefined;
#            find_tag = cookie.output().split("=")[1][4:]
#            self.write("{}\n".format(find_tag))# , cookie['expires'], cookie.output())



def main():
    http_server = tornado.httpserver.HTTPServer(Application())
    http_server.listen(8002)
    tornado.ioloop.IOLoop.instance().start()


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-ec7b00757911> in <module>
#     130
#     131 if __name__ == "__main__":
# --> 132     main()
#
# <ipython-input-1-ec7b00757911> in main()
#     126     http_server = tornado.httpserver.HTTPServer(Application())
#     127     http_server.listen(8002)
# --> 128     tornado.ioloop.IOLoop.instance().start()
#     129
#     130
#
# c:\users\billaidon\appdata\local\programs\python\python37\lib\site-packages\tornado\platform\asyncio.py in start(self)
#     147             self._setup_logging()
#     148             asyncio.set_event_loop(self.asyncio_loop)
# --> 149             self.asyncio_loop.run_forever()
#     150         finally:
#     151             asyncio.set_event_loop(old_loop)
#
# c:\users\billaidon\appdata\local\programs\python\python37\lib\asyncio\base_events.py in run_forever(self)
#     523         self._check_closed()
#     524         if self.is_running():
# --> 525             raise RuntimeError('This event loop is already running')
#     526         if events._get_running_loop() is not None:
#     527             raise RuntimeError(
#
# RuntimeError: This event loop is already running
